# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# given function
def fx(x):
  return np.sin(x)

# %%
#data to visulize function in interval [3,4]
xmin, xmax = -10,5 # points for visualization
# ploting givven function
dx = 0.05;  x=np.arange(xmin,xmax, dx); y=fx(x)
plt.xlabel("x"); plt.ylabel("y"); plt.plot(x, y, 'b'); plt.grid()
# ploting bracketing points
xs = 2
plt.plot([xs], [0], 'or')

# %% [markdown]
# Newton

# %%
def dfx(x):
  h = 1e-6
  return (fx(x) - fx(x-h)) / h

# %%
eps = 1e-8
xi = xs
while np.abs(fx(xi)) > eps:
  xi_bef = xi
  xi = xi - (1 / dfx(xi)) * fx(xi)
  print("Fx = " + str(fx(xi)) + "  /  x = " + str(xi))
  plt.xlabel("x"); plt.ylabel("y"); plt.plot(x, y, 'b'); plt.grid()
  plt.plot([xi_bef], fx(xi_bef), 'ob')
  plt.plot([xi], [0], 'or')
  plt.plot([xi_bef, xi], [fx(xi_bef), 0], 'r-')
  plt.plot([xi, xi], [0, fx(xi)], 'g--')
  plt.show()
print("done")
# Out:
# Fx = -0.8641453486818075  /  x = 4.185042250987611
# Fx = 0.6238854220159962  /  x = 2.4678881084858895
# Fx = -0.12427535339846046  /  x = 3.266190143171581
# Fx = 0.0006487940019571084  /  x = 3.1409438595423196
# Fx = -9.115274057072423e-11  /  x = 3.141592653680946
# done
